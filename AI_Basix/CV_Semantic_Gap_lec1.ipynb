# %%
class Cat:
  def __init__(self, ref_cat_img):
    self.ref_cat_features = self.get_features(ref_cat_img)
    
  def is_cat(self, cat_img):
    features = self.get_features(cat_img)
    return self.compare_features(features, self.ref_cat_features)
    
  def get_features(cat_img):
    
    features = []# eyes, ears,....
    
  def compare_features(self, cat_img_features, ref_img_features):
    for feature1, feature2 in enumerate(zip(cat_img_features, ref_img_features)):
      if feature1 != feature2
        return False
    return True

# %%
cat = Cat()
cat.is_cat(cat_img)

# %%
# !wget http://www.petsworld.in/blog/wp-content/uploads/2014/09/cat.jpg
# Out:
# --2019-03-07 09:38:15--  http://www.petsworld.in/blog/wp-content/uploads/2014/09/cat.jpg
# Resolving www.petsworld.in (www.petsworld.in)... 139.99.124.2
# Connecting to www.petsworld.in (www.petsworld.in)|139.99.124.2|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 47687 (47K) [image/jpeg]
# Saving to: ‘cat.jpg’
#
# cat.jpg             100%[===================>]  46.57K   101KB/s    in 0.5s
#
# 2019-03-07 09:38:16 (101 KB/s) - ‘cat.jpg’ saved [47687/47687]

# %%
import cv2
img = cv2.imread('cat.jpg')

# %%
import matplotlib.pyplot as plt
plt.imshow(img, cmap='gray')

# %%
from keras.preprocessing import image
img = image.load_img('cat.jpg')
plt.imshow(img)
# Out:
# Using TensorFlow backend.

# %%
img_tensor = image.img_to_array(img)
img_tensor
# Out:
# array([[[255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.],
#         ...,
#         [255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.]],
#
#        [[255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.],
#         ...,
#         [255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.]],
#
#        [[255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.],
#         ...,
#         [255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.]],
#
#        ...,
#
#        [[255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.],
#         ...,
#         [255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.]],
#
#        [[255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.],
#         ...,
#         [255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.]],
#
#        [[255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.],
#         ...,
#         [255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.]]], dtype=float32)

# %%
img_tensor.shape
# Out:
# (600, 400, 3)

# %%
# !wget https://png.pngtree.com/element_origin_min_pic/16/11/26/1edb59a685922cd6b3ce107e7f203051.jpg
# Out:
# --2019-03-07 09:53:35--  https://png.pngtree.com/element_origin_min_pic/16/11/26/1edb59a685922cd6b3ce107e7f203051.jpg
# Resolving png.pngtree.com (png.pngtree.com)... 13.35.115.25, 13.35.115.35, 13.35.115.121, ...
# Connecting to png.pngtree.com (png.pngtree.com)|13.35.115.25|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 85437 (83K) [binary/octet-stream]
# Saving to: ‘1edb59a685922cd6b3ce107e7f203051.jpg.1’
#
# 1edb59a685922cd6b3c 100%[===================>]  83.43K  --.-KB/s    in 0.04s
#
# 2019-03-07 09:53:35 (1.90 MB/s) - ‘1edb59a685922cd6b3ce107e7f203051.jpg.1’ saved [85437/85437]

# %%
img2 = image.load_img('1edb59a685922cd6b3ce107e7f203051.jpg')
plt.imshow(img2)
