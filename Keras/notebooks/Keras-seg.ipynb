# %% [markdown]
# https://divamgupta.com/image-segmentation/2019/06/06/deep-learning-semantic-segmentation-keras.html

# %%
#!pip install keras-segmentation # Needs data preparation
# Out:
# ...
#   Stored in directory: /root/.cache/pip/wheels/10/43/34/8d5a4aaa8d4479380c3aef57abf90ac47aa1e062c772defa39
# Successfully built keras-segmentation
# ...

# %%
# !git clone https://github.com/Kautenja/semantic-segmentation-baselines.git
# Out:
# Cloning into 'semantic-segmentation-baselines'...
# remote: Enumerating objects: 4317, done.
# remote: Total 4317 (delta 0), reused 0 (delta 0), pack-reused 4317
# Receiving objects: 100% (4317/4317), 1.76 GiB | 32.11 MiB/s, done.
# Resolving deltas: 100% (1761/1761), done.
# Checking out files: 100% (1523/1523), done.
