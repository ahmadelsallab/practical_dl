# %% [markdown]
# #<font color='red'>Question 1</font>
# __Describe the difference between AI, ML,  DL?__

# %% [markdown]
# - AI is divided into rule-based or learning based approaches
# - ML is to learn the rule (model), but the features (representations) are designed
# - DL is to learn both the rule (model) and features (representation)

# %% [markdown]
# #<font color='red'>Question 2</font>
# #What are the branches of ML, and describe each
# </font>

# %% [markdown]
# - Supervised learning: Data is composed of input data and desired or target outputs, and we wish to learn good prediction models. Example: ConvNets for image classification
# - Unsupervised learning: Data is composed of just raw data, and we wish to learn a good representation. Example: clustering.
# - Self-supervised learning: same as supervised, but the target labels are obtained without human effort
# - Reinforcement Learning: Similar to learning in mamals. It involves an Agent and an Environment. The Agent learns a Policy by interacting with the environment and receiving rewards and penalties.

# %% [markdown]
# #<font color='red'>Question 3</font>
# __Describe each of the following terms:__
#
# ## Write your answer next to each of them after double clicking the cell:
#
# - __Sample or input__
#
#
# - __Prediction or output__
#
# - __Target or Label__
#
# - __Prediction error or loss value__
#
# - __Classes__
#
# - __Ground-truth or annotations__
#
# - __Binary classification__
#
# - __Multiclass classification__
#
# - __Multilabel classification__
#
# - __Scalar regression__
#
# - __Vector regression__
#
# - __Mini-batch or batch__

# %% [markdown]
# - __Sample or input__—One data point that goes into your model.
# - __Prediction or output__—What comes out of your model.
# - __Target__—The truth. What your model should ideally have predicted, according
# to an external source of data.
#
# - __Prediction error or loss value__—A measure of the distance between your
# model’s prediction and the target.
# - __Classes__—A set of possible labels to choose from in a classification problem.
# For example, when classifying cat and dog pictures, “dog” and “cat” are the
# two classes.
# - __Label__—A specific instance of a class annotation in a classification problem.
# For instance, if picture #1234 is annotated as containing the class “dog,”
# then “dog” is a label of picture #1234.
# - __Ground-truth or annotations__—All targets for a dataset, typically collected by
# humans.
# - __Binary classification__—A classification task where each input sample should
# be categorized into two exclusive categories.
# - __Multiclass classification__—A classification task where each input sample
# should be categorized into more than two categories: for instance, classifying
# handwritten digits.
# - __Multilabel classification__—A classification task where each input sample can
# be assigned multiple labels. For instance, a given image may contain both a
# cat and a dog and should be annotated both with the “cat” label and the
# “dog” label. The number of labels per image is usually variable.
# - __Scalar regression__—A task where the target is a continuous scalar value. Predicting
# house prices is a good example: the different target prices form a continuous
# space.
# - __Vector regression__—A task where the target is a set of continuous values: for
# example, a continuous vector. If you’re doing regression against multiple values
# (such as the coordinates of a bounding box in an image), then you’re
# doing vector regression.
# - __Mini-batch or batch__—A small set of samples (typically between 8 and 128)
# that are processed simultaneously by the model. The number of samples is
# often a power of 2, to facilitate memory allocation on GPU. When training, a
# mini-batch is used to compute a single gradient-descent update applied to
# the weights of the model.

# %% [markdown]
# #<font color='red'>Question 4</font>
#
# __What is the difference between Classification and Regression?__

# %% [markdown]
# - Classification: given an input data, predict its class out of discrete K-categories. Example: cats/dogs image classification.
# - Regression: given an input, predict a continous output. Example: House prices prediction based on data about the house location, area,....

# %% [markdown]
# #<font color='red'>Question 5</font>
# __How do you evaluate ML model? Describe the protocol and the datasets types needed__

# %% [markdown]
# we split the data into a __training set__, a __validation set__, and a __test set__.
#
# You train on the training data and evaluate your model
# on the validation data. Once your model is ready for prime time, you test it one final
# time on the test data.

# %% [markdown]
# #<font color='red'>Question 6 </font>
# __Why we need a validation set? Describe different spliting methods of data__
#
# __When you need to use cross validation?__

# %% [markdown]
# You may ask, why not have two sets: a training set and a test set? You’d train on the
# training data and evaluate on the test data. Much simpler!
# The reason is that developing a model always involves tuning its configuration: for
# example, choosing the number of layers or the size of the layers (called the __hyperparameters__
# of the model, to distinguish them from the __parameters__, which are the network’s
# _weights_). You do this tuning by using as a feedback signal the performance of
# the model on the validation data.
#
# # Splitting methods:
# 1- Simple hold-out
# 2- K-Fold
# 3- Iterated K-Folds
#
# # Cross-validation
#
# When you don't have enough training data to split into val-train.
#
# This method is helpful when the performance of your model shows significant variance based on your traintest split. Like hold-out validation, this method doesn’t exempt you from using a distinct validation set for model calibration.

# %% [markdown]
# #<font color='red'>Question 7</font>
# __What is the difference between overfitting and underfitting?__

# %% [markdown]
# # Overfitting:
# The reason not to evaluate the models on the same data
# they were trained on quickly became evident: after just a few epochs, all three models
# began to __overfit__. That is, their performance on never-before-seen data started stalling
# (or worsening) compared to their performance on the training data—which always
# improves as training progresses.
#
# In machine learning, the goal is to achieve models that __generalize__—that perform
# well on never-before-seen data—and overfitting is the central obstacle.
#
# # Underfitting:
# An ML model is trained on the training data, and evaluated on test data. Sometimes the model capacity is not even enough to perform well on training data, which is called undefitting.

# %% [markdown]
# #<font color='red'>Question 8</font>
#
#
# __Mention the five steps to avoid overfitting__

# %% [markdown]
# 1- More data
# 2- Data augmentation
# 3- Generalizable architectures
# 4- Regularization
# 5- Reduce model size/complexity

# %% [markdown]
# #<font color='red'>Question 9</font>
#
# __Mention the 7 steps of universal ML workflow__

# %% [markdown]
# 1. Defining the problem and assembling a dataset
# 2. Choosing a measure of success
# 3. Deciding on an evaluation protocol
# 4. Preparing your data
# 5. Developing a model that does better than a baseline
# 6. Scaling up: developing a model that overfits
# 7. Regularizing your model and tuning your hyperparameters

# %% [markdown]
# #<font color='red'>Question 10</font>
#
# __For each of the following problem types, mention the proper loss function and output activation:__
#
# - Binary classification
#
# - Multi-class, single label classification
#
# - Multi-class, multi label classification
#
# - Regression with arbitrary output
#
# - Regreression with (0,1) output

# %% [markdown]
# Binary classification:
#
# loss=binary_crossentropy, output_activation=sigmoid
#
# Multi-class, single label classification:
#
# loss=categorical_crossentropy or sparse_categorical_crossentropy, output_activation=softmax
#
# Multi-class, multi label classification:
#
# loss=binary_crossentropy, output_activation=sigmoid
#
# Regression with arbitrary output:
#
# loss=mse, output_activation=None
#
# Regreression with (0,1) output:
#
# loss=binary_crossentropy or mse, output_activation=sigmoid

# %% [markdown]
# #<font color='red'>Question 11</font>
#
# __Describe the Convolution layers in brief, their advantages over Dense, and when to use them?__

# %% [markdown]
# __Dense is global while Conv is local__
#
#
# ___Key conv properties___:
# - The patterns they learn are ___translation invariant___
#
# After learning a certain pattern in the lower-right corner of a picture, a convnet can recognize it ___anywhere___:
#
# for example, in the upper-left corner. A densely connected network would have to learn the pattern anew if it appeared at a new location.
#
# This makes convnets ___data efficient___ when processing images (because the visual world is fundamentally translation invariant):
#
# they need _fewer training samples_ to learn representations that have generalization power.
#
# - They can learn ___spatial hierarchies___ of patterns
# the visual world is fundamentally spatially hierarchical

# %% [markdown]
# #<font color='red'>Question 12</font>
#
# __What are the main design parameters to Conv2D layers?__

# %% [markdown]
# - Kernel size (LxW)
# - Depth: Number of output kernels
# - Stride
# - Pad
# - Activation

# %% [markdown]
# #<font color='red'>Question 13</font>
#
# __Roughtly, how many training examples you need for K-classes classification problem?__
#
# __What would you do if you have small of insuffuicient data?__

# %% [markdown]
# 5000 example per class--> for K-classes we need 5000 * K examples
#
# For small data we can use transfer learning

# %% [markdown]
# #<font color='red'>Question 14</font>
#
# You have a pre-trained ConvNet (conv_base), and you want to use transfer learning from that model to your problem.
#
# __What are the different Transfer Learning scenarios you can use the pre-trained ConvNet with your model?__

# %% [markdown]
# - Feature extraction: fix the conv_base
# - Fine-tuning: train some top layers or all layers from conv_base
# - Pre-trained model: use conv_base+classification layer (whole pre-trained net) as is

# %% [markdown]
# #<font color='red'>Question 15</font>
#
# You think to fine tune the conv_base.
#
#
# __How do you decide what type of transfer learning you should perform on a new dataset?__

# %% [markdown]
# This is a function of several factors, but the two most important ones:
#
# __A- are the size of the new dataset (small or big), and__
#
# __B- its similarity to the original dataset__
#
#
# Based on that, we have 4 cases:
#
#
# 1- ___New dataset is small and similar to original dataset___.
#
# _The best idea might be to train a linear classifier on the CNN codes._
#
# __Max Reuse, No Fine-tune__
#
# 2- ___New dataset is large and similar to the original dataset___.
#
# Since we have more data, we can have more confidence that we won’t overfit if we were to try to _fine-tune through the full network._
#
# __Max Reuse, Fine-tune__
#
# 3- ___New dataset is small but very different from the original dataset___.
#
# Since the data is small, it is likely best to only train a linear classifier. Since the dataset is very different, it might not be best to train the classifier form the top of the network, which contains more dataset-specific features.
#
# Instead, it might work better to _train the classifier from activations somewhere earlier in the network._
#
# __Min Reuse, No Fine-tune__
#
# 4- ___New dataset is large and very different from the original dataset___. Since the dataset is very large, we may expect that we can afford to train a ConvNet from scratch. However, in practice it is very often still beneficial to initialize with weights from a pretrained model.
#
# _In this case, we would have enough data and confidence to fine-tune through the entire network._
#
# __NoReuse, Fine-tune__
# __No need to transfer__
